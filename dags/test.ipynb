# %%
string = "SCO, AKX, SAH, ALA, AYK, ATX, GUW, BXH, EKB, KGF, KOV, KSN, KZO, NQZ, URA, UKK, PWQ, PPK, PLX, CIT, TDK, DMB, HSA, UZR, USJ, SZI, DZN"

kaz_iata = []

for iata in string:
    kaz_iata.append(iata)

kaz_iata
# Out:
# ['S',
#  'C',
#  'O',
#  ' ',
#  'A',
#  'K',
#  'X',
#  ' ',
#  'S',
#  'A',
#  'H',
#  ' ',
#  'A',
#  'L',
#  'A',
#  ' ',
#  'A',
#  'Y',
#  'K',
#  ' ',
#  'A',
#  'T',
#  'X',
#  ' ',
#  'G',
#  'U',
#  'W',
#  ' ',
#  'B',
#  'X',
#  'H',
#  ' ',
#  'E',
#  'K',
#  'B',
#  ' ',
#  'K',
#  'G',
#  'F',
#  ' ',
#  'K',
#  'O',
#  'V',
#  ' ',
#  'K',
#  'S',
#  'N',
#  ' ',
#  'K',
#  'Z',
#  'O',
#  ' ',
#  'N',
#  'Q',
#  'Z',
#  ' ',
#  'U',
#  'R',
#  'A',
#  ' ',
#  'U',
#  'K',
#  'K',
#  ' ',
#  'P',
#  'W',
#  'Q',
#  ' ',
#  'P',
#  'P',
#  'K',
#  ' ',
#  'P',
#  'L',
#  'X',
#  ' ',
#  'C',
#  'I',
#  'T',
#  ' ',
#  'T',
#  'D',
#  'K',
#  ' ',
#  'D',
#  'M',
#  'B',
#  ' ',
#  'H',
#  'S',
#  'A',
#  ' ',
#  'U',
#  'Z',
#  'R',
#  ' ',
#  'U',
#  'S',
#  'J',
#  ' ',
#  'S',
#  'Z',
#  'I',
#  ' ',
#  'D',
#  'Z',
#  'N']
