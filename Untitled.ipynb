# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# %%
iata = "ALA"
key = "e731e10ffd59f5dee0f69b8c26460607"
offset = 0
df = pd.DataFrame()
anal_columns = [
    'flight_date', 
    'flight_status', 
    'departure.airport', 
    'departure.terminal', 
    'departure.scheduled', 
    'departure.actual',
    'departure.delay',
    'arrival.airport', 
    'arrival.baggage',
    'arrival.scheduled',
    'flight.codeshared.airline_name',
]
prev_date = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

print(f"Yesterday was: {prev_date}")

def download_json(url):
    response = requests.get(url)
    response.raise_for_status()  # Raises HTTPError for 4xx or 5xx responses
    return response.json()

while True:
    url = f"http://api.aviationstack.com/v1/flights?access_key={key}&dep_iata={iata}&offset={offset}"
    temp_json = download_json(url)
    df = pd.concat([df, pd.json_normalize(temp_json['data'])])
    pd.json_normalize(data_1['data'])
    print(f"Offset = {offset}")
    if int(temp_json["pagination"]["count"]) < 100:
        break
    else:
        offset += 100
        
def sort_df(date):
    selected_columns = df[anal_columns]
    filtered_df = selected_columns[df['flight_date'] == date]
    sorted_df = filtered_df.sort_values(by='departure.scheduled', ascending=True)
    return sorted_df

sort_df(prev_date)
# Out:
# Yesterday was: 2024-03-28
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 29
#      27 while True:
#      28     url = f"http://api.aviationstack.com/v1/flights?access_key={key}&dep_iata={iata}&offset={offset}"
# ---> 29     temp_json = download_json(url)
#      30     df = pd.concat([df, pd.json_normalize(temp_json['data'])])
#      31     pd.json_normalize(data_1['data'])
#
# Cell In[4], line 24, in download_json(url)
#      22 def download_json(url):
#      23     response = requests.get(url)
# ---> 24     response.raise_for_status()  # Raises HTTPError for 4xx or 5xx responses
#      25     return response.json()
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: Internal Server Error for url: http://api.aviationstack.com/v1/flights?access_key=e731e10ffd59f5dee0f69b8c26460607&dep_iata=ALA&offset=0

# %%
bucket_name = "de-project-flight-analyzer"
iata = "ALA"
url_base = f"http://api.aviationstack.com/v1/flights?access_key=4c9daccbaa0ab0dc63923014205e07c3&dep_iata={iata}"
offset = 0
json_data = []

def download_data(url):
    response = requests.get(url)
    response.raise_for_status()  # Raise an HTTPError for bad responses
    return response.json()

while True:
    url = f"{url_base}&offset={offset}"
    temp_json = download_data(url)
    json_data.extend(temp_json["data"])
    if int(temp_json["pagination"]["count"]) < 100:
        break
    else:
        offset += 100

# %%
prev_date = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')
df = pd.json_normalize(json_data)
for column in df.columns:
    print(f"'{column}',")
    
df['airline.name']
# Out:
# 'flight_date',
# 'flight_status',
# 'aircraft',
# 'live',
# 'departure.airport',
# 'departure.timezone',
# 'departure.iata',
# 'departure.icao',
# 'departure.terminal',
# 'departure.gate',
# 'departure.delay',
# 'departure.scheduled',
# 'departure.estimated',
# 'departure.actual',
# 'departure.estimated_runway',
# 'departure.actual_runway',
# 'arrival.airport',
# 'arrival.timezone',
# 'arrival.iata',
# 'arrival.icao',
# 'arrival.terminal',
# 'arrival.gate',
# 'arrival.baggage',
# 'arrival.delay',
# 'arrival.scheduled',
# 'arrival.estimated',
# 'arrival.actual',
# 'arrival.estimated_runway',
# 'arrival.actual_runway',
# 'airline.name',
# 'airline.iata',
# 'airline.icao',
# 'flight.number',
# 'flight.iata',
# 'flight.icao',
# 'flight.codeshared',
# 'aircraft.registration',
# 'aircraft.iata',
# 'aircraft.icao',
# 'aircraft.icao24',
# 'live.updated',
# 'live.latitude',
# 'live.longitude',
# 'live.altitude',
# 'live.direction',
# 'live.speed_horizontal',
# 'live.speed_vertical',
# 'live.is_ground',
# 'flight.codeshared.airline_name',
# 'flight.codeshared.airline_iata',
# 'flight.codeshared.airline_icao',
# 'flight.codeshared.flight_number',
# 'flight.codeshared.flight_iata',
# 'flight.codeshared.flight_icao',
# 0         ASL Airlines Belgium
# 1                SCAT Airlines
# 2                   Air Astana
# 3                   Air Astana
# 4                SCAT Airlines
#                 ...
# 320    China Southern Airlines
# 321            Asiana Airlines
# 322            Asiana Airlines
# 323              SCAT Airlines
# 324                  Red Wings
# Name: airline.name, Length: 325, dtype: object

# %%
sort_df(prev_date)
# Out:
#     flight_date flight_status departure.airport departure.terminal  \
# 210  2024-03-25        landed            Almaty               None
# 209  2024-03-25        landed            Almaty               None
# 208  2024-03-25        landed            Almaty               None
# 159  2024-03-25        landed            Almaty               None
# 158  2024-03-25        landed            Almaty               None
# ..          ...           ...               ...                ...
# 270  2024-03-25        landed            Almaty               None
# 196  2024-03-25        active            Almaty               None
# 200  2024-03-25        active            Almaty               None
# 229  2024-03-25     scheduled            Almaty               None
# 228  2024-03-25        landed            Almaty               None
#
#            departure.scheduled           departure.actual  departure.delay  \
# 210  2024-03-25T00:15:00+00:00  2024-03-25T00:27:00+00:00             12.0
# 209  2024-03-25T00:15:00+00:00  2024-03-25T00:27:00+00:00             12.0
# 208  2024-03-25T00:15:00+00:00  2024-03-25T00:27:00+00:00             12.0
# 159  2024-03-25T00:25:00+00:00  2024-03-25T00:31:00+00:00              7.0
# 158  2024-03-25T00:25:00+00:00  2024-03-25T00:31:00+00:00              7.0
# ..                         ...                        ...              ...
# 270  2024-03-25T23:20:00+00:00  2024-03-25T23:38:00+00:00             19.0
# 196  2024-03-25T23:30:00+00:00  2024-03-25T23:36:00+00:00              6.0
# 200  2024-03-25T23:30:00+00:00  2024-03-25T23:36:00+00:00              6.0
# 229  2024-03-25T23:45:00+00:00                       None              NaN
# 228  2024-03-25T23:45:00+00:00  2024-03-26T00:04:00+00:00             20.0
#
#                                 arrival.airport arrival.baggage  \
# 210                             Seoul (Incheon)              22
# 209                             Seoul (Incheon)              22
# 208                             Seoul (Incheon)              22
# 159                  Suvarnabhumi International            None
# 158                  Suvarnabhumi International            None
# ..                                          ...             ...
# 270  Nursultan Nazarbayev International Airport            None
# 196                        Atyrau International            None
# 200                        Atyrau International            None
# 229                                 Krasnojarsk            None
# 228                                 Krasnojarsk            None
#
#              arrival.scheduled flight.codeshared.airline_name
# 210  2024-03-25T09:55:00+00:00                     air astana
# 209  2024-03-25T09:55:00+00:00                            NaN
# 208  2024-03-25T09:55:00+00:00                     air astana
# 159  2024-03-25T08:55:00+00:00                            NaN
# 158  2024-03-25T08:55:00+00:00                     air astana
# ..                         ...                            ...
# 270  2024-03-26T01:05:00+00:00                            NaN
# 196  2024-03-26T02:50:00+00:00                            NaN
# 200  2024-03-26T02:50:00+00:00                     air astana
# 229  2024-03-26T04:30:00+00:00                            NaN
# 228  2024-03-26T04:30:00+00:00                            NaN
#
# [175 rows x 11 columns]

# %%
df = df.drop_duplicates(subset=["arrival.airport", "departure.scheduled"], keep='first')
sort_df(prev_date)
# Out:
#     flight_date flight_status departure.airport departure.terminal  \
# 208  2024-03-25        landed            Almaty               None
# 158  2024-03-25        landed            Almaty               None
# 207  2024-03-25        landed            Almaty               None
# 252  2024-03-25        landed            Almaty               None
# 201  2024-03-25        landed            Almaty               None
# ..          ...           ...               ...                ...
# 306  2024-03-25        landed            Almaty               None
# 271  2024-03-25        landed            Almaty               None
# 270  2024-03-25        landed            Almaty               None
# 196  2024-03-25        active            Almaty               None
# 228  2024-03-25        landed            Almaty               None
#
#            departure.scheduled           departure.actual  departure.delay  \
# 208  2024-03-25T00:15:00+00:00  2024-03-25T00:27:00+00:00             12.0
# 158  2024-03-25T00:25:00+00:00  2024-03-25T00:31:00+00:00              7.0
# 207  2024-03-25T00:30:00+00:00  2024-03-25T00:48:00+00:00             19.0
# 252  2024-03-25T01:10:00+00:00  2024-03-25T01:48:00+00:00             38.0
# 201  2024-03-25T02:00:00+00:00  2024-03-25T02:04:00+00:00              4.0
# ..                         ...                        ...              ...
# 306  2024-03-25T22:20:00+00:00  2024-03-25T22:28:00+00:00              8.0
# 271  2024-03-25T23:05:00+00:00  2024-03-25T23:22:00+00:00             17.0
# 270  2024-03-25T23:20:00+00:00  2024-03-25T23:38:00+00:00             19.0
# 196  2024-03-25T23:30:00+00:00  2024-03-25T23:36:00+00:00              6.0
# 228  2024-03-25T23:45:00+00:00  2024-03-26T00:04:00+00:00             20.0
#
#                                       arrival.airport arrival.baggage  \
# 208                                   Seoul (Incheon)              22
# 158                        Suvarnabhumi International            None
# 207                              Phuket International            None
# 252        Nursultan Nazarbayev International Airport            None
# 201  Heydar Aliyev International (Bina International)            None
# ..                                                ...             ...
# 306                        Sheremetyevo International               1
# 271        Nursultan Nazarbayev International Airport            None
# 270        Nursultan Nazarbayev International Airport            None
# 196                              Atyrau International            None
# 228                                       Krasnojarsk            None
#
#              arrival.scheduled flight.codeshared.airline_name
# 208  2024-03-25T09:55:00+00:00                     air astana
# 158  2024-03-25T08:55:00+00:00                     air astana
# 207  2024-03-25T09:30:00+00:00                            NaN
# 252  2024-03-25T03:10:00+00:00                      lufthansa
# 201  2024-03-25T05:00:00+00:00                            NaN
# ..                         ...                            ...
# 306  2024-03-26T01:20:00+00:00                            NaN
# 271  2024-03-26T00:50:00+00:00                            NaN
# 270  2024-03-26T01:05:00+00:00                            NaN
# 196  2024-03-26T02:50:00+00:00                            NaN
# 228  2024-03-26T04:30:00+00:00                            NaN
#
# [120 rows x 11 columns]

# %%
iata = "NQZ"

def fetch_data():
        url_base = f"http://api.aviationstack.com/v1/flights?access_key=e731e10ffd59f5dee0f69b8c26460607&dep_iata={iata}"
        offset = 0
        output_json = []

        while True:
            url = f"{url_base}&offset={offset}"
            response = requests.get(url)
            response.raise_for_status()
            data = response.json()
            temp_json = data.get('data', [])
            output_json.extend(temp_json)

            if int(data["pagination"]["count"]) < 100:
                break

            offset += 100
        
        return output_json
        
print(fetch_data())
# Out:
# [{'flight_date': '2024-03-27', 'flight_status': 'scheduled', 'departure': {'airport': 'Nursultan Nazarbayev International Airport', 'timezone': None, 'iata': 'NQZ', 'icao': 'UACC', 'terminal': '2', 'gate': None, 'delay': None, 'scheduled': '2024-03-27T15:00:00+00:00', 'estimated': '2024-03-27T15:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Aktyubinsk', 'timezone': 'Asia/Aqtobe', 'iata': 'AKX', 'icao': 'UATT', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-27T16:40:00+00:00', 'estimated': '2024-03-27T16:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'SCAT Airlines', 'iata': 'DV', 'icao': 'VSV'}, 'flight': {'number': '721', 'iata': 'DV721', 'icao': 'VSV721', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-27', 'flight_status': 'scheduled', 'departure': {'airport': 'Nursultan Nazarbayev International Airport', 'timezone': None, 'iata': 'NQZ', 'icao': 'UACC', 'terminal': '2', 'gate': None, 'delay': None, 'scheduled': '2024-03-27T17:20:00+00:00', 'estimated': '2024-03-27T17:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Hazret Sultan International Airport', 'timezone': None, 'iata': 'HSA', 'icao': 'UAIT', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-27T19:20:00+00:00', 'estimated': '2024-03-27T19:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Qazaq Air', 'iata': 'IQ', 'icao': 'QAZ'}, 'flight': {'number': '369', 'iata': 'IQ369', 'icao': 'QAZ369', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-27', 'flight_status': 'scheduled', 'departure': {'airport': 'Nursultan Nazarbayev International Airport', 'timezone': None, 'iata': 'NQZ', 'icao': 'UACC', 'terminal': '2', 'gate': None, 'delay': None, 'scheduled': '2024-03-27T07:20:00+00:00', 'estimated': '2024-03-27T07:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Aktyubinsk', 'timezone': 'Asia/Aqtobe', 'iata': 'AKX', 'icao': 'UATT', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-27T08:20:00+00:00', 'estimated': '2024-03-27T08:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Qazaq Air', 'iata': 'IQ', 'icao': 'QAZ'}, 'flight': {'number': '399', 'iata': 'IQ399', 'icao': 'QAZ399', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-27', 'flight_status': 'active', 'departure': {'airport': 'Nursultan Nazarbayev International Airport', 'timezone': None, 'iata': 'NQZ', 'icao': 'UACC', 'terminal': '1', 'gate': None, 'delay': 4, 'scheduled': '2024-03-27T13:55:00+00:00', 'estimated': '2024-03-27T13:55:00+00:00', 'actual': '2024-03-27T13:59:00+00:00', 'estimated_runway': '2024-03-27T13:59:00+00:00', 'actual_runway': '2024-03-27T13:59:00+00:00'}, 'arrival': {'airport': 'Koltsovo International', 'timezone': 'Asia/Yekaterinburg', 'iata': 'SVX', 'icao': 'USSS', 'terminal': 'I', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-27T15:50:00+00:00', 'estimated': '2024-03-27T15:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Red Wings', 'iata': 'WZ', 'icao': 'RWZ'}, 'flight': {'number': '1098', 'iata': 'WZ1098', 'icao': 'RWZ1098', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-27', 'flight_status': 'scheduled', 'departure': {'airport': 'Nursultan Nazarbayev International Airport', 'timezone': None, 'iata': 'NQZ', 'icao': 'UACC', 'terminal': '2', 'gate': None, 'delay': None, 'scheduled': '2024-03-27T20:00:00+00:00', 'estimated': '2024-03-27T20:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Aktyubinsk', 'timezone': 'Asia/Aqtob ...

# %%
from pyspark.sql import SparkSession

def upload_to_bigquery():
    bucket_name = "de-project-flight-analyzer"
    iata = "NQZ"
    prev_date = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')
    columns = [
        'departure.airport',
        'departure.iata',
        'departure.timezone',
        'departure.scheduled',
        'departure.actual',
        'departure.delay',
        'arrival.airport',
        'arrival.iata',
        'arrival.timezone',
        'arrival.scheduled',
        'arrival.actual',
        'arrival.delay',
        'airline.name',
        'airline.iata',
        'flight.number',
        'flight.iata',
    ]
    
    spark = SparkSession.builder \
        .appName("GCS Access") \
        .config("spark.hadoop.fs.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem") \
        .config("spark.hadoop.google.cloud.auth.service.account.enable", "true") \
        .config("spark.hadoop.google.cloud.auth.service.account.json.keyfile", "/Users/ramazanabylkassov/Desktop/Programming & Data science/Projects/aviation_stack_project/GC_creds/de-project-flight-analyzer-3354c85abe73.json") \
        .getOrCreate()

    df = spark.read.parquet(f"gs://{bucket_name}/{iata}/{prev_date}/*")

    df_columns = df \
        .select(columns)

    df_columns.registerTempTable('temp_table')

    df_result = spark.sql("""
    WITH asd AS (
        SELECT 
            *,
            ROW_NUMBER() OVER (PARTITION BY departure.airport, arrival.airport, departure.scheduled ORDER BY (NULL)) AS rn
        FROM temp_table
    )
    SELECT
        CAST('departure.airport' AS STRING) AS departure.airport,
        CAST('departure.iata' AS STRING) AS departure.iata,
        CAST('departure.timezone' AS TIMESTAMP) AS departure.timezone,
        CAST('departure.scheduled' AS TIMESTAMP) AS departure.scheduled,
        CAST('departure.actual' AS TIMESTAMP) AS departure.actual,
        CAST('departure.delay' AS INTEGER) AS departure.delay,
        CAST('arrival.airport' AS TIMESTAMP) AS arrival.airport,
        CAST('arrival.iata' AS STRING) AS arrival.iata,
        CAST('arrival.timezone' AS TIMESTAMP) AS arrival.timezone,
        CAST('arrival.scheduled' AS TIMESTAMP) AS arrival.scheduled,
        CAST('arrival.actual' AS TIMESTAMP) AS arrival.actual,
        CAST('arrival.delay' AS INTEGER) AS arrival.delay,
        CAST('airline.name' AS STRING) AS airline.name,
        CAST('airline.iata' AS STRING) AS airline.iata,
        CAST('flight.number' AS INTEGER) AS flight.number,
        CAST('flight.iata' AS STRING) AS flight.iata,
    FROM asd
    WHERE rn = 1
    """)
    
    return df_result

#     # Save the data to BigQuery
#     df_result.write.format('bigquery') \
#     .option('table', df_result) \
#     .save()

df_spark = upload_to_bigquery()
df_spark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pyspark.sql import SparkSession
#       3 def upload_to_bigquery():
#       4     bucket_name = "de-project-flight-analyzer"
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
! pip show pyspark
# Out:
# Name: pyspark
# Version: 3.5.1
# Summary: Apache Spark Python API
# Home-page: https://github.com/apache/spark/tree/master/python
# Author: Spark Developers
# Author-email: dev@spark.apache.org
# License: http://www.apache.org/licenses/LICENSE-2.0
# Location: /Users/ramazanabylkassov/Desktop/Programming & Data science/Projects/aviation_stack_project/.venv/lib/python3.10/site-packages
# Requires: py4j
# Required-by:
